# %%
import pandas as pd
from pycaret.clustering import setup, create_model, assign_model, plot_model, save_model, load_model, predict_model
import json
from openai import OpenAI
from dotenv import dotenv_values
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, Distance, VectorParams
import streamlit as st

# %%
env=dotenv_values('.env')

openai_client= OpenAI(api_key=env['OPENAI_API_KEY'])

#openai_client= OpenAI(api_key=env['api_key'])

# %%
df=pd.read_csv('welcome_survey_simple_v2.csv', sep=";")

# %%
kmeans_pipeline=load_model('clustering_pipeline_v2')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
df.head()
# Out:
#      age   edu_level      fav_animals fav_place     gender
# 0    <18  Podstawowe  Brak ulubionych       NaN    Kobieta
# 1  25-34     Średnie              Psy  Nad wodą  Mężczyzna
# 2  45-54      Wyższe              Psy   W lesie  Mężczyzna
# 3  35-44     Średnie             Koty  W górach  Mężczyzna
# 4  35-44      Wyższe              Psy  Nad wodą  Mężczyzna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          229 non-null    object
#  1   edu_level    229 non-null    object
#  2   fav_animals  229 non-null    object
#  3   fav_place    200 non-null    object
#  4   gender       227 non-null    object
# dtypes: object(5)
# memory usage: 9.1+ KB

# %%
len(df)
df
# Out:
#        age   edu_level      fav_animals fav_place     gender
# 0      <18  Podstawowe  Brak ulubionych       NaN    Kobieta
# 1    25-34     Średnie              Psy  Nad wodą  Mężczyzna
# 2    45-54      Wyższe              Psy   W lesie  Mężczyzna
# 3    35-44     Średnie             Koty  W górach  Mężczyzna
# 4    35-44      Wyższe              Psy  Nad wodą  Mężczyzna
# ..     ...         ...              ...       ...        ...
# 224  35-44      Wyższe             Koty      Inne    Kobieta
# 225  45-54      Wyższe             Inne   W lesie  Mężczyzna
# 226  25-34      Wyższe              Psy  W górach  Mężczyzna
# 227  35-44      Wyższe  Brak ulubionych  W górach  Mężczyzna
# 228  45-54      Wyższe             Koty  Nad wodą  Mężczyzna
#
# [229 rows x 5 columns]

# %%
s=setup(df, session_id=123)
s
# Out:
# <style type="text/css">
# #T_abeeb_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_abeeb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abeeb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_abeeb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abeeb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abeeb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_abeeb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abeeb_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_abeeb_row1_col1" class="data row1 col1" >(229, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abeeb_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_abeeb_row2_col1" class="data row2 col1" >(229, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abeeb_row3_col0" class="data row3 col0" >Categorical features</td>
#       <td id="T_abeeb_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abeeb_row4_col0" class="data row4 col0" >Rows with missing values</td>
#       <td id="T_abeeb_row4_col1" class="data row4 col1" >13.1%</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_abeeb_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_abeeb_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_abeeb_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_abeeb_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_abeeb_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_abeeb_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_abeeb_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_abeeb_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_abeeb_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_abeeb_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_abeeb_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_abeeb_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_abeeb_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_abeeb_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_abeeb_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_abeeb_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_abeeb_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_abeeb_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_abeeb_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_abeeb_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_abeeb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_abeeb_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_abeeb_row15_col1" class="data row15 col1" >78ab</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.dataset.head()
# Out:
#      age   edu_level      fav_animals fav_place     gender
# 0    <18  Podstawowe  Brak ulubionych       NaN    Kobieta
# 1  25-34     Średnie              Psy  Nad wodą  Mężczyzna
# 2  45-54      Wyższe              Psy   W lesie  Mężczyzna
# 3  35-44     Średnie             Koty  W górach  Mężczyzna
# 4  35-44      Wyższe              Psy  Nad wodą  Mężczyzna

# %%
kmeans=create_model('kmeans', num_clusters=12)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0cd21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cd21_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0cd21_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0cd21_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0cd21_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0cd21_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0cd21_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cd21_row0_col0" class="data row0 col0" >0.2148</td>
#       <td id="T_0cd21_row0_col1" class="data row0 col1" >21.6655</td>
#       <td id="T_0cd21_row0_col2" class="data row0 col2" >1.7164</td>
#       <td id="T_0cd21_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0cd21_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0cd21_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_with_clusters= assign_model(kmeans)
df_with_clusters
# Out:
#        age   edu_level      fav_animals fav_place     gender     Cluster
# 0      <18  Podstawowe  Brak ulubionych       NaN    Kobieta   Cluster 7
# 1    25-34     Średnie              Psy  Nad wodą  Mężczyzna  Cluster 10
# 2    45-54      Wyższe              Psy   W lesie  Mężczyzna   Cluster 3
# 3    35-44     Średnie             Koty  W górach  Mężczyzna   Cluster 4
# 4    35-44      Wyższe              Psy  Nad wodą  Mężczyzna   Cluster 0
# ..     ...         ...              ...       ...        ...         ...
# 224  35-44      Wyższe             Koty      Inne    Kobieta   Cluster 2
# 225  45-54      Wyższe             Inne   W lesie  Mężczyzna   Cluster 3
# 226  25-34      Wyższe              Psy  W górach  Mężczyzna   Cluster 8
# 227  35-44      Wyższe  Brak ulubionych  W górach  Mężczyzna   Cluster 2
# 228  45-54      Wyższe             Koty  Nad wodą  Mężczyzna   Cluster 5
#
# [229 rows x 6 columns]

# %%
df_with_clusters['Cluster'].value_counts()
# Out:
# Cluster
# Cluster 0     36
# Cluster 3     25
# Cluster 8     25
# Cluster 1     24
# Cluster 6     24
# Cluster 2     20
# Cluster 5     20
# Cluster 4     16
# Cluster 10    14
# Cluster 11    10
# Cluster 7      8
# Cluster 9      7
# Name: count, dtype: int64

# %%
save_model(kmeans,'clustering_pipeline_v2.pkl', verbose=False)
# Out:
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=[], transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['age', 'edu_level', 'fav_animals',
#                                               'fav_place', 'gender'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['gender'],
#                                      transfo...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': Kobieta      0
#  Mężczyzna    1
#  NaN         -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['age', 'edu_level', 'fav_animals',
#                                               'fav_place'],
#                                      transformer=OneHotEncoder(cols=['age',
#                                                                      'edu_level',
#                                                                      'fav_animals',
#                                                                      'fav_place'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('trained_model', KMeans(n_clusters=12, random_state=123))]),
#  'clustering_pipeline_v2.pkl.pkl')

# %%
#kmeans_pipeline=load_model('clustering_pipeline_v2')
kmeans_pipeline
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=[], transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['age', 'edu_level', 'fav_animals',
#                                              'fav_place', 'gender'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('ordinal_encoding',
#                  TransformerWrapper(include=['gender'],
#                                     transfo...
#                                                                          'data_type': dtype('O'),
#                                                                          'mapping': Kobieta      0
# Mężczyzna    1
# NaN         -1
# dtype: int64}]))),
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['age', 'edu_level', 'fav_animals',
#                                              'fav_place'],
#                                     transformer=OneHotEncoder(cols=['age',
#                                                                     'edu_level',
#                                                                     'fav_animals',
#                                                                     'fav_place'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('trained_model', KMeans(n_clusters=12, random_state=123))])

# %%
df_with_clusters=predict_model(model=kmeans_pipeline, data=df)

# %%
df_with_clusters['Cluster'].value_counts()
# Out:
# Cluster
# Cluster 0     36
# Cluster 3     25
# Cluster 8     25
# Cluster 1     24
# Cluster 6     24
# Cluster 2     20
# Cluster 5     20
# Cluster 4     16
# Cluster 10    14
# Cluster 11    10
# Cluster 7      8
# Cluster 9      7
# Name: count, dtype: int64

# %%
cluster_descriptions={}
for cluster_id in df_with_clusters['Cluster'].unique():
    cluster_df= df_with_clusters[df_with_clusters['Cluster']==cluster_id]
    summary=""
    for column in df_with_clusters:
        if column=='Cluster':
            continue

        value_counts=cluster_df[column].value_counts()
        value_counts_str=','.join([f"{idx}: {cnt}" for idx, cnt in value_counts.items()])
        summary+=f"{column}- {value_counts_str}\n"
    cluster_descriptions[cluster_id]=summary

# %%
print(cluster_descriptions["Cluster 11"])
# Out:
# age- 25-34: 8,45-54: 2,18-24: 0,35-44: 0,55-64: 0,<18: 0,>=65: 0,unknown: 0
# edu_level- Wyższe: 10,Podstawowe: 0,Średnie: 0
# fav_animals- Koty: 8,Brak ulubionych: 1,Inne: 1,Koty i Psy: 0,Psy: 0
# fav_place- W górach: 7,Nad wodą: 1,Inne: 0,W lesie: 0
# gender- Mężczyzna: 9,Kobieta: 1

# %%
prompt="Użyliśmu algorytmu klastrowania"
for cluster_id, descriptions in cluster_descriptions.items():
    prompt+= f"\nKlaster{cluster_id}:\n{descriptions}"

prompt+="""
Wygeneruj najlepsze możliwe opisy dla każdego z klasterów. Proszę wygenerować najlepsze nazwy dla każdego z klastrów oraz ich opisy w formacie JSON.

Uzyje formatu JSON.Przykładowo:
{
    "Cluster 0": {
        "name": "Klaster 0",
        "description": "W tym klastrze znajdują się osoby, które..."
    },
    "Cluster 1": {
        "name": "Klaster 1",
        "description": "W tym klastrze znajdują się osoby, które..."
    }
"""
print(prompt)
# Out:
# Użyliśmu algorytmu klastrowania
# KlasterCluster 7:
# age- 35-44: 6,45-54: 1,<18: 1,18-24: 0,25-34: 0,55-64: 0,>=65: 0,unknown: 0
# edu_level- Średnie: 7,Podstawowe: 1,Wyższe: 0
# fav_animals- Psy: 3,Brak ulubionych: 2,Koty: 2,Inne: 1,Koty i Psy: 0
# fav_place- Nad wodą: 4,W lesie: 1,Inne: 0,W górach: 0
# gender- Kobieta: 6,Mężczyzna: 2
#
# KlasterCluster 10:
# age- 45-54: 5,18-24: 4,25-34: 2,35-44: 2,>=65: 1,55-64: 0,<18: 0,unknown: 0
# edu_level- Średnie: 14,Podstawowe: 0,Wyższe: 0
# fav_animals- Psy: 14,Brak ulubionych: 0,Inne: 0,Koty: 0,Koty i Psy: 0
# fav_place- Nad wodą: 8,W górach: 4,W lesie: 1,Inne: 0
# gender- Mężczyzna: 14,Kobieta: 0
#
# KlasterCluster 3:
# age- 45-54: 18,55-64: 4,35-44: 2,>=65: 1,18-24: 0,25-34: 0,<18: 0,unknown: 0
# edu_level- Wyższe: 25,Podstawowe: 0,Średnie: 0
# fav_animals- Psy: 12,Brak ulubionych: 5,Koty: 5,Inne: 3,Koty i Psy: 0
# fav_place- W lesie: 25,Inne: 0,Nad wodą: 0,W górach: 0
# gender- Mężczyzna: 19,Kobieta: 6
#
# KlasterCluster 4:
# age- 25-34: 5,35-44: 4,45-54: 4,18-24: 3,55-64: 0,<18: 0,>=65: 0,unknown: 0
# edu_level- Średnie: 16,Podstawowe: 0,Wyższe: 0
# fav_animals- Inne: 6,Koty: 4,Brak ulubionych: 3,Psy: 3,Koty i Psy: 0
# fav_place- W górach: 14,Inne: 2,Nad wodą: 0,W lesie: 0
# gender- Mężczyzna: 14,Kobieta: 2
#
# KlasterCluster 0:
# age- 35-44: 36,18-24: 0,25-34: 0,45-54: 0,55-64: 0,<18: 0,>=65: 0,unknown: 0
# edu_level- Wyższe: 36,Podstawowe: 0,Średnie: 0
# fav_animals- Psy: 23,Brak ulubionych: 5,Inne: 5,Koty: 3,Koty i Psy: 0
# fav_place- Nad wodą: 28,Inne: 1,W górach: 0,W lesie: 0
# gender- Mężczyzna: 26,Kobieta: 10
#
# KlasterCluster 8:
# age- 25-34: 19,35-44: 6,18-24: 0,45-54: 0,55-64: 0,<18: 0,>=65: 0,unknown: 0
# edu_level- Wyższe: 25,Podstawowe: 0,Średnie: 0
# fav_animals- Psy: 23,Inne: 2,Brak ulubionych: 0,Koty: 0,Koty i Psy: 0
# fav_place- W lesie: 13,W górach: 6,Nad wodą: 4,Inne: 1
# gender- Mężczyzna: 17,Kobieta: 8
#
# KlasterCluster 11:
# age- 25-34: 8,45-54: 2,18-24: 0,35-44: 0,55-64: 0,<18: 0,>=65: 0,unknown: 0
# edu_level- Wyższe: 10,Podstawowe: 0,Średnie: 0
# fav_animals- Koty: 8,Brak ulubionych: 1,Inne: 1,Koty i Psy: 0,Psy: 0
# fav_place- W górach: 7,Nad wodą: 1,Inne: 0,W lesie: 0
# gender- Mężczyzna: 9,Kobieta: 1
#
# KlasterCluster 1:
# age- 45-54: 13,35-44: 8,18-24: 1,55-64: 1,>=65: 1,25-34: 0,<18: 0,unknown: 0
# edu_level- Wyższe: 24,Podstawowe: 0,Średnie: 0
# fav_animals- Psy: 19,Brak ulubionych: 3,Inne: 2,Koty: 0,Koty i Psy: 0
# fav_place- W górach: 24,Inne: 0,Nad wodą: 0,W lesie: 0
# gender- Mężczyzna: 19,Kobieta: 4
#
# KlasterCluster 2:
# age- 35-44: 19,>=65: 1,18-24: 0,25-34: 0,45-54: 0,55-64: 0,<18: 0,unknown: 0
# edu_level- Wyższe: 20,Podstawowe: 0,Średnie: 0
# fav_animals- Koty: 8,Brak ulubionych: 4,Inne: 4,Koty i Psy: 2,Psy: 2
# fav_place- W górach: 18,Inne: 2,Nad wodą: 0,W lesie: 0
# gender- Mężczyzna: 12,Kobieta: 8
#
# KlasterCluster 5:
# age- 45-54: 12,55-64: 5,18-24: 1,>=65: 1,unknown: 1,25-34: 0,35-44: 0,<18: 0
# edu_level- Wyższe: 20,Podstawowe: 0,Średnie: 0
# fav_animals- Inne: 8,Koty: 5,Koty i Psy: 4,Brak ulubionych: 3,Psy: 0
# fav_place- Nad wodą: 10,Inne: 1,W górach: 0,W lesie: 0
# gender- Mężczyzna: 16,Kobieta: 3
#
# KlasterCluster 9:
# age- 25-34: 3,45-54: 3,18-24: 1,35-44: 0,55-64: 0,<18: 0,>=65: 0,unknown: 0
# edu_level- Średnie: 7,Podstawowe: 0,Wyższe: 0
# fav_animals- Koty: 6,Inne: 1,Brak ulubionych: 0,Koty i Psy: 0,Psy: 0
# fav_place- W lesie: 5,Inne: 1,Nad wodą: 0,W górach: 0
# gender- Mężczyzna: 7,Kobieta: 0
#
# KlasterCluster 6:
# age- 45-54: 16,55-64: 5,>=65: 2,unknown: 1,18-24: 0,25-34: 0,35-44: 0,<18: 0
# edu_level- Wyższe: 24,Podstawowe: 0,Średnie: 0
# fav_animals- Psy: 24,Brak ulubionych: 0,Inne: 0,Koty: 0,Koty i Psy: 0
# fav_place- Nad wodą: 18,Inne: 1,W górach: 0,W lesie: 0
# gender- Mężczyzna: 16,Kobieta: 8
#
# Wygeneruj najlepsze możliwe opisy dla każdego z klasterów. Proszę wygenerować najlepsze nazwy dla każdego z klastrów oraz ich opisy w formacie JSON.
#
# Uzyje formatu JSON.Przykładowo:
# {
#     "Cluster 0": {
#         "name": "Klaster 0",
#         "description": "W tym klastrze znajdują się osoby, które..."
#     },
#     "Cluster 1": {
#         "name": "Klaster 1",
#         "description": "W tym klastrze znajdują się osoby, które..."
#     }

# %%
response=openai_client.chat.completions.create(
    model='gpt-4o',
    temperature=0,
    messages=[
        {
            'role':'user',
            'content':[{'type':'text', 'text':prompt}]
        }
    ]
    
)

# %%
result = response.choices[0].message.content.replace("```json", "").replace("```", "").strip()
cluster_names_and_descriptions = json.loads(result)

# %%
with open("welcome_survey_cluster_names_and_descriptions_v1.json", "w") as f:
    f.write(json.dumps(cluster_names_and_descriptions))

# %%
with open('welcome_survey_cluster_names_and_descriptions_v1.json','r') as f:
    print(json.loads(f.read()))
# Out:
# {'Cluster 0': {'name': 'Młodzi profesjonaliści nad wodą', 'description': 'W tym klastrze znajdują się osoby w wieku 35-44 lat, z wyższym wykształceniem, które preferują spędzanie czasu nad wodą. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są psy.'}, 'Cluster 1': {'name': 'Doświadczeni górscy entuzjaści', 'description': 'W tym klastrze znajdują się osoby w wieku 45-54 lat, z wyższym wykształceniem, które preferują spędzanie czasu w górach. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są psy.'}, 'Cluster 2': {'name': 'Miłośnicy kotów i gór', 'description': 'W tym klastrze znajdują się osoby w wieku 35-44 lat, z wyższym wykształceniem, które preferują spędzanie czasu w górach. Wśród ulubionych zwierząt dominują koty, a większość z nich to mężczyźni.'}, 'Cluster 3': {'name': 'Wykształceni leśni odkrywcy', 'description': 'W tym klastrze znajdują się osoby w wieku 45-54 lat, z wyższym wykształceniem, które preferują spędzanie czasu w lesie. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są psy, choć niektórzy nie mają ulubionych zwierząt.'}, 'Cluster 4': {'name': 'Młodzi górscy odkrywcy', 'description': 'W tym klastrze znajdują się osoby w wieku 25-34 lat, z średnim wykształceniem, które preferują spędzanie czasu w górach. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są różne gatunki, w tym koty i inne.'}, 'Cluster 5': {'name': 'Doświadczeni miłośnicy wody', 'description': 'W tym klastrze znajdują się osoby w wieku 45-54 lat, z wyższym wykształceniem, które preferują spędzanie czasu nad wodą. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są różne gatunki, w tym koty i inne.'}, 'Cluster 6': {'name': 'Doświadczeni miłośnicy psów nad wodą', 'description': 'W tym klastrze znajdują się osoby w wieku 45-54 lat, z wyższym wykształceniem, które preferują spędzanie czasu nad wodą. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są psy.'}, 'Cluster 7': {'name': 'Średnio wykształcone kobiety nad wodą', 'description': 'W tym klastrze znajdują się głównie kobiety w wieku 35-44 lat, z średnim wykształceniem, które preferują spędzanie czasu nad wodą. Ich ulubionymi zwierzętami są psy, choć niektóre nie mają ulubionych zwierząt.'}, 'Cluster 8': {'name': 'Młodzi wykształceni leśni odkrywcy', 'description': 'W tym klastrze znajdują się osoby w wieku 25-34 lat, z wyższym wykształceniem, które preferują spędzanie czasu w lesie. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są psy.'}, 'Cluster 9': {'name': 'Średnio wykształceni miłośnicy kotów', 'description': 'W tym klastrze znajdują się osoby w wieku 25-34 lat, z średnim wykształceniem, które preferują spędzanie czasu w lesie. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są koty.'}, 'Cluster 10': {'name': 'Średnio wykształceni miłośnicy psów', 'description': 'W tym klastrze znajdują się osoby w wieku 45-54 lat, z średnim wykształceniem, które preferują spędzanie czasu nad wodą. Wszyscy członkowie tego klastra to mężczyźni, a ich ulubionymi zwierzętami są psy.'}, 'Cluster 11': {'name': 'Młodzi wykształceni miłośnicy kotów', 'description': 'W tym klastrze znajdują się osoby w wieku 25-34 lat, z wyższym wykształceniem, które preferują spędzanie czasu w górach. Większość z nich to mężczyźni, a ich ulubionymi zwierzętami są koty.'}}

# %%
st.write("Predicted cluster ID:", predicted_cluster_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 st.write("Predicted cluster ID:", predicted_cluster_id)
#
# NameError: name 'predicted_cluster_id' is not defined
